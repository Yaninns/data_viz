# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaninns/data_viz/blob/main/Quiz4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
data = pd.read_excel('passenger-covid19.xlsx',sheet_name='Data63-64',skiprows=1)
data.head()
# Out:
#     ขนคน (คน)  ทางบก  การเดินทางระหว่างจังหวัด  ...      61158      51204      58371
# 0   ขนคน (คน)  ทางบก  การเดินทางระหว่างจังหวัด  ...        NaN        NaN        NaN
# 1   ขนคน (คน)  ทางบก  การเดินทางระหว่างจังหวัด  ...    16432.0    11373.0    12455.0
# 2  ขนคน (คัน)  ทางบก  การเดินทางระหว่างจังหวัด  ...   930045.0   940739.0   870772.0
# 3  ขนคน (คัน)  ทางบก  การเดินทางระหว่างจังหวัด  ...  1649220.0  1348121.0  1211478.0
# 4  ขนคน (คัน)  ทางบก  การเดินทางระหว่างจังหวัด  ...  1594994.0  1305116.0  1192083.0
#
# [5 rows x 445 columns]

# %%
data_25 = data.rename(columns={'Unnamed: 5':'ราคาเสนอ','Unnamed: 7':'ราคาซื้อ'})
